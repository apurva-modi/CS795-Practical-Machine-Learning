# %% [markdown]
# # A Quick Demo of Named Entity Recognition using spacy

# %%
import spacy

# %%
article = '''The Seattle metro area is now home to the stock market's only two trillion-dollar companies: Amazon joined neighbor Microsoft in that exclusive club Thursday. Amazon (AMZN) briefly topped the trillion-dollar mark for the first time since September. At that time, both Amazon and Apple were worth more than a trillion dollars. Apple (AAPL) shares have since pulled back a bit. The iPhone maker is now worth about $920 billion.
Big Tech stocks have soared this year, despite concerns about the possibility of more regulation in the United States and worldwide as well as trade tension between the United States and China. So far, their sales and earnings growth have remained relatively strong.
Microsoft (MSFT), which is now worth nearly $1.1 trillion, is the most valuable company on the planet. It has soared 36% thanks to optimism about its cloud business.'''

# %% [markdown]
# pip install spacy
#
#
# python -m spacy download en

# %%
spacy_nlp = spacy.load('en_core_web_sm')
document = spacy_nlp(article)

# %% [markdown]
# ## Named Entity Recognition

# %%
print('Original Sentence: %s' % (article))

for element in document.ents:
    print('Type: %s, Value: %s' % (element.label_, element))
# Out:
# Original Sentence: The Seattle metro area is now home to the stock market's only two trillion-dollar companies: Amazon joined neighbor Microsoft in that exclusive club Thursday. Amazon (AMZN) briefly topped the trillion-dollar mark for the first time since September. At that time, both Amazon and Apple were worth more than a trillion dollars. Apple (AAPL) shares have since pulled back a bit. The iPhone maker is now worth about $920 billion.
# Big Tech stocks have soared this year, despite concerns about the possibility of more regulation in the United States and worldwide as well as trade tension between the United States and China. So far, their sales and earnings growth have remained relatively strong.
# Microsoft (MSFT), which is now worth nearly $1.1 trillion, is the most valuable company on the planet. It has soared 36% thanks to optimism about its cloud business.
# Type: GPE, Value: Seattle
# Type: MONEY, Value: only two trillion-dollar
# Type: ORG, Value: Amazon
# ...

# %% [markdown]
# ![image.png](attachment:image.png)
